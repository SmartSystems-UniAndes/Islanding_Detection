# %% [markdown]
# # Islanding detection based on CNN
# In this notebook, convolutional neural networks are used in order to detect islanding events extracted from a Matlab/Simulink simulation. The dataset was gathered using a 100kW grid-connected photovoltaic system based on https://www.mathworks.com/help/physmod/sps/ug/detailed-model-of-a-100-kw-grid-connected-pv-array.html. The diagram of the model can be seen in the next image:
#
# ![Title](img/simulink_model_pic.png)
#
#
# The dataset was constructed by changing the active power of a Load connected at the point of common coupling through values between 90kW and 110kW. First, the voltage at each phase in the point of common coupling was measured and concatenated in a single array. Then, this time-series data was  converted into images using the wavelet tranform with a Morlet wavelet, generating the dataset used for this project. Each event in the dataset was generated at time 0.2s in the simulation. The voltage used was measured between seconds 0.2s and 0.35s. The sample rate for the data generated was 2e-05s. The scenarios included in the dataset can be seen in the following table:
#
# | - |Grid-connected C_ON|Grid-connected C_OFF|Sudden swithcing OFF C|Sudden switching ON C| Islanding event C_ON  | Islanding event C_OFF | LL-fault | LN-fault | Total |
# |---| --- | --- | --- | --- | --- |--- |--- | --- | --- |
# | # Events | 100 | 100 | 100 | 100 | 100 |  100 | 100 | 100 | 800 |
# | Label | 0 | 1 | 2 | 3 | 4 | 5 | 6 | 7 | --- |

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
from jupyterthemes import jtplot
jtplot.style()
import os

# %% [markdown]
# In the next cell, several images from the different scenarios in the dataset collected are ploted. As it can be seen, many of the images seem to be the same when they are not.

# %%
f, axarr = plt.subplots(4,2, figsize=(20,20))
images = os.listdir("./img/graphs")
counter = 0
for a in range(len(axarr)):
    for b in range(len(axarr[a])):
        img = image.load_img("./img/graphs/" + images[counter])
        axarr[a,b].axis('off')
        axarr[a,b].imshow(img)
        axarr[a,b].set_title(images[counter][:images[counter].find(".png")])
        counter += 1

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
def graficarMatrizConfusion(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  

    plt.figure(figsize=(8,8))

    ax = sns.heatmap(cm, annot = True, cbar = False);
      
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
      
    plt.xlabel("Predicted Class")
    plt.ylabel("True Class")
    plt.title("Confussion Matrix")

    plt.show()

# %% [markdown]
# The next cell extracts the dataset from the .mat file generated. Each image had a size of (224, 224, 3). The dataset is composed of three columns, the first column corresponds to the value of the load at the moment of generating the the data, the second column corresponds to the image generated from the wavelet transform and the thrid column has the label of the data selected.

# %%
from scipy.io import loadmat
import numpy as np
import h5py
filename = "dataset_IDM.mat"
with h5py.File(filename, 'r') as f:
    ref_label = np.array(f['dataset']['label'])
    labels = np.array([int(np.array(f[f['dataset']['label'][i][0]]).squeeze()) for i in range(0, len(ref_label))])
    images = np.array([np.array(f[f['dataset']['data'][i][0]]).squeeze() for i in range(0, len(ref_label))]).reshape(-1,224,224,3)

# %%
import matplotlib.image as mpimg
from PIL import Image
imgplot = plt.imshow(np.clip(images[701], 0, 1))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# We proceed to separate the dataset between training and testing values in the next cell.

# %%
x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size = 0.33, random_state = 42)

# %% [markdown]
# ### Convolutional Neural Network Model

# %%
tf.random.set_seed(51)
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), input_shape = (224, 224, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(32, activation = 'relu'),
    tf.keras.layers.Dense(8, activation='softmax')
    ])
model.summary()
model.compile(loss='sparse_categorical_crossentropy', optimizer = 'adam', metrics = ['sparse_categorical_accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 52, 52, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 26, 26, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 43264)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1384480
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 264
# =================================================================
# Total params: 1,408,328
# Trainable params: 1,408,328
# Non-trainable params: 0
# _________________________________________________________________

# %%
#X_train, X_test, y_train, y_test = train_test_split(dataset[0][], , test_size=0.33, random_state=42)
model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 2s 67ms/step - loss: 2.1707 - sparse_categorical_accuracy: 0.1638 - val_loss: 1.6110 - val_sparse_categorical_accuracy: 0.3902
# Epoch 2/100
# 17/17 [==============================] - 1s 37ms/step - loss: 1.4845 - sparse_categorical_accuracy: 0.4424 - val_loss: 1.2197 - val_sparse_categorical_accuracy: 0.6288
# Epoch 3/100
# 17/17 [==============================] - 1s 36ms/step - loss: 1.1060 - sparse_categorical_accuracy: 0.6641 - val_loss: 1.0709 - val_sparse_categorical_accuracy: 0.6705
# Epoch 4/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.9752 - sparse_categorical_accuracy: 0.6834 - val_loss: 0.7374 - val_sparse_categorical_accuracy: 0.6288
# Epoch 5/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.8400 - sparse_categorical_accuracy: 0.6276 - val_loss: 0.5741 - val_sparse_categorical_accuracy: 0.7992
# Epoch 6/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.7826 - sparse_categorical_accuracy: 0.7197 - val_loss: 0.5360 - val_sparse_categorical_accuracy: 0.7576
# Epoch 7/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.6049 - sparse_categorical_accuracy: 0.7337 - val_loss: 0.4691 - val_sparse_categorical_accuracy: 0.7992
# Epoch 8/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.5352 - sparse_categorical_accuracy: 0.7311 - val_loss: 0.5919 - val_sparse_categorical_accuracy: 0.7462
# Epoch 9/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.5203 - sparse_categorical_accuracy: 0.7663 - val_loss: 0.5576 - val_sparse_categorical_accuracy: 0.7992
# Epoch 10/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.6370 - sparse_categorical_accuracy: 0.7456 - val_loss: 0.5725 - val_sparse_categorical_accuracy: 0.7462
# Epoch 11/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.6012 - sparse_categorical_accuracy: 0.7035 - val_loss: 0.4410 - val_sparse_categorical_accuracy: 0.7992
# Epoch 12/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4866 - sparse_categorical_accuracy: 0.7666 - val_loss: 0.4541 - val_sparse_categorical_accuracy: 0.7576
# Epoch 13/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4842 - sparse_categorical_accuracy: 0.7407 - val_loss: 0.4091 - val_sparse_categorical_accuracy: 0.7576
# Epoch 14/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4507 - sparse_categorical_accuracy: 0.7612 - val_loss: 0.4521 - val_sparse_categorical_accuracy: 0.7992
# Epoch 15/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.5127 - sparse_categorical_accuracy: 0.7547 - val_loss: 0.4237 - val_sparse_categorical_accuracy: 0.7462
# Epoch 16/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4836 - sparse_categorical_accuracy: 0.7467 - val_loss: 0.5798 - val_sparse_categorical_accuracy: 0.7576
# Epoch 17/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.4987 - sparse_categorical_accuracy: 0.7550 - val_loss: 0.4202 - val_sparse_categorical_accuracy: 0.7992
# Epoch 18/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.5266 - sparse_categorical_accuracy: 0.7443 - val_loss: 0.4679 - val_sparse_categorical_accuracy: 0.7992
# Epoch 19/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.5404 - sparse_categorical_accuracy: 0.7197 - val_loss: 0.4567 - val_sparse_categorical_accuracy: 0.7462
# Epoch 20/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4792 - sparse_categorical_accuracy: 0.7338 - val_loss: 0.4152 - val_sparse_categorical_accuracy: 0.7992
# Epoch 21/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.5231 - sparse_categorical_accuracy: 0.7483 - val_loss: 0.4358 - val_sparse_categorical_accuracy: 0.7992
# Epoch 22/100
# 17/17 [==============================] - 1s 38ms/step - loss: 0.5229 - sparse_categorical_accuracy: 0.7193 - val_loss: 0.4058 - val_sparse_categorical_accuracy: 0.7462
# Epoch 23/100
# 17/17 [==============================] - 1s 38ms/step - loss: 0.4591 - sparse_categorical_accuracy: 0.7818 - val_loss: 0.4346 - val_sparse_categorical_accuracy: 0.7462
# Epoch 24/100
# 17/17 [==============================] - 1s 38ms/step - loss: 0.4377 - sparse_categorical_accuracy: 0.7915 - val_loss: 0.3681 - val_sparse_categorical_accuracy: 0.7992
# Epoch 25/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4216 - sparse_categorical_accuracy: 0.7630 - val_loss: 0.4206 - val_sparse_categorical_accuracy: 0.7576
# Epoch 26/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4611 - sparse_categorical_accuracy: 0.7425 - val_loss: 0.3996 - val_sparse_categorical_accuracy: 0.7462
# Epoch 27/100
# 17/17 [==============================] - 1s 38ms/step - loss: 0.4556 - sparse_categorical_accuracy: 0.7503 - val_loss: 0.3635 - val_sparse_categorical_accuracy: 0.7992
# Epoch 28/100
# 17/17 [==============================] - 1s 38ms/step - loss: 0.4041 - sparse_categorical_accuracy: 0.7772 - val_loss: 0.3780 - val_sparse_categorical_accuracy: 0.7992
# Epoch 29/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4306 - sparse_categorical_accuracy: 0.7593 - val_loss: 0.3623 - val_sparse_categorical_accuracy: 0.9053
# Epoch 30/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.4682 - sparse_categorical_accuracy: 0.7468 - val_loss: 0.3961 - val_sparse_categorical_accuracy: 0.7992
# Epoch 31/100
# 17/17 [==============================] - 1s 38ms/step - loss: 0.4585 - sparse_categorical_accuracy: 0.7559 - val_loss: 0.3831 - val_sparse_categorical_accuracy: 0.7992
# Epoch 32/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4485 - sparse_categorical_accuracy: 0.7538 - val_loss: 0.4029 - val_sparse_categorical_accuracy: 0.7576
# Epoch 33/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.4134 - sparse_categorical_accuracy: 0.7874 - val_loss: 0.3898 - val_sparse_categorical_accuracy: 0.7576
# Epoch 34/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.3990 - sparse_categorical_accuracy: 0.7987 - val_loss: 0.3825 - val_sparse_categorical_accuracy: 0.8523
# Epoch 35/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.4034 - sparse_categorical_accuracy: 0.8491 - val_loss: 0.5481 - val_sparse_categorical_accuracy: 0.7576
# Epoch 36/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.4105 - sparse_categorical_accuracy: 0.7918 - val_loss: 0.3859 - val_sparse_categorical_accuracy: 0.7462
# Epoch 37/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.3763 - sparse_categorical_accuracy: 0.7997 - val_loss: 0.3242 - val_sparse_categorical_accuracy: 0.9053
# Epoch 38/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4059 - sparse_categorical_accuracy: 0.7908 - val_loss: 0.3696 - val_sparse_categorical_accuracy: 0.7462
# Epoch 39/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.4387 - sparse_categorical_accuracy: 0.7581 - val_loss: 0.3700 - val_sparse_categorical_accuracy: 0.7576
# Epoch 40/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.4071 - sparse_categorical_accuracy: 0.7527 - val_loss: 0.3655 - val_sparse_categorical_accuracy: 0.8523
# Epoch 41/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.3918 - sparse_categorical_accuracy: 0.8451 - val_loss: 0.3219 - val_sparse_categorical_accuracy: 0.9053
# Epoch 42/100
# 17/17 [==============================] - 1s 38ms/step - loss: 0.3389 - sparse_categorical_accuracy: 0.8289 - val_loss: 0.3038 - val_sparse_categorical_accuracy: 0.9053
# Epoch 43/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.3320 - sparse_categorical_accuracy: 0.8549 - val_loss: 0.3655 - val_sparse_categorical_accuracy: 0.7576
# Epoch 44/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.3959 - sparse_categorical_accuracy: 0.7647 - val_loss: 0.2996 - val_sparse_categorical_accuracy: 0.9053
# Epoch 45/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.3802 - sparse_categorical_accuracy: 0.7835 - val_loss: 0.3482 - val_sparse_categorical_accuracy: 0.7992
# Epoch 46/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.3488 - sparse_categorical_accuracy: 0.7770 - val_loss: 0.2874 - val_sparse_categorical_accuracy: 0.9053
# Epoch 47/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.3359 - sparse_categorical_accuracy: 0.8618 - val_loss: 0.4141 - val_sparse_categorical_accuracy: 0.8523
# Epoch 48/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.3899 - sparse_categorical_accuracy: 0.8425 - val_loss: 0.2835 - val_sparse_categorical_accuracy: 0.9091
# Epoch 49/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.3613 - sparse_categorical_accuracy: 0.7977 - val_loss: 0.2998 - val_sparse_categorical_accuracy: 0.8523
# Epoch 50/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.3001 - sparse_categorical_accuracy: 0.8723 - val_loss: 0.2605 - val_sparse_categorical_accuracy: 0.9053
# Epoch 51/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.3220 - sparse_categorical_accuracy: 0.8624 - val_loss: 0.2711 - val_sparse_categorical_accuracy: 0.8523
# Epoch 52/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2959 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.2478 - val_sparse_categorical_accuracy: 1.0000
# Epoch 53/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.3235 - sparse_categorical_accuracy: 0.8903 - val_loss: 0.3030 - val_sparse_categorical_accuracy: 0.8523
# Epoch 54/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2873 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.2345 - val_sparse_categorical_accuracy: 0.9053
# Epoch 55/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2986 - sparse_categorical_accuracy: 0.8625 - val_loss: 0.2390 - val_sparse_categorical_accuracy: 0.9053
# Epoch 56/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2408 - sparse_categorical_accuracy: 0.8882 - val_loss: 0.2276 - val_sparse_categorical_accuracy: 0.8523
# Epoch 57/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.2368 - sparse_categorical_accuracy: 0.9291 - val_loss: 0.2262 - val_sparse_categorical_accuracy: 0.8523
# Epoch 58/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2407 - sparse_categorical_accuracy: 0.8829 - val_loss: 0.2132 - val_sparse_categorical_accuracy: 0.8523
# Epoch 59/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2217 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.2261 - val_sparse_categorical_accuracy: 0.9053
# Epoch 60/100
# 17/17 [==============================] - 1s 34ms/step - loss: 0.2438 - sparse_categorical_accuracy: 0.8918 - val_loss: 0.2665 - val_sparse_categorical_accuracy: 0.8523
# Epoch 61/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2652 - sparse_categorical_accuracy: 0.8775 - val_loss: 0.2497 - val_sparse_categorical_accuracy: 0.9053
# Epoch 62/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.2713 - sparse_categorical_accuracy: 0.8839 - val_loss: 0.2390 - val_sparse_categorical_accuracy: 0.8523
# Epoch 63/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.2285 - sparse_categorical_accuracy: 0.8894 - val_loss: 0.2523 - val_sparse_categorical_accuracy: 0.8523
# Epoch 64/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2530 - sparse_categorical_accuracy: 0.8724 - val_loss: 0.2202 - val_sparse_categorical_accuracy: 0.9053
# Epoch 65/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.2469 - sparse_categorical_accuracy: 0.8739 - val_loss: 0.1823 - val_sparse_categorical_accuracy: 1.0000
# Epoch 66/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1872 - sparse_categorical_accuracy: 0.9054 - val_loss: 0.1965 - val_sparse_categorical_accuracy: 0.9053
# Epoch 67/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.2246 - sparse_categorical_accuracy: 0.8666 - val_loss: 0.1841 - val_sparse_categorical_accuracy: 0.9053
# Epoch 68/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1956 - sparse_categorical_accuracy: 0.8958 - val_loss: 0.1702 - val_sparse_categorical_accuracy: 0.9053
# Epoch 69/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2044 - sparse_categorical_accuracy: 0.8961 - val_loss: 0.1930 - val_sparse_categorical_accuracy: 0.8523
# Epoch 70/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.2127 - sparse_categorical_accuracy: 0.9054 - val_loss: 0.2060 - val_sparse_categorical_accuracy: 0.8523
# Epoch 71/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.2039 - sparse_categorical_accuracy: 0.8868 - val_loss: 0.1672 - val_sparse_categorical_accuracy: 0.9053
# Epoch 72/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2188 - sparse_categorical_accuracy: 0.8780 - val_loss: 0.2222 - val_sparse_categorical_accuracy: 0.9053
# Epoch 73/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.2651 - sparse_categorical_accuracy: 0.8901 - val_loss: 0.2551 - val_sparse_categorical_accuracy: 0.8523
# Epoch 74/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2523 - sparse_categorical_accuracy: 0.8653 - val_loss: 0.2695 - val_sparse_categorical_accuracy: 0.8523
# Epoch 75/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.2276 - sparse_categorical_accuracy: 0.8812 - val_loss: 0.1660 - val_sparse_categorical_accuracy: 1.0000
# Epoch 76/100
# 17/17 [==============================] - ETA: 0s - loss: 0.1826 - sparse_categorical_accuracy: 0.912 - 1s 36ms/step - loss: 0.1845 - sparse_categorical_accuracy: 0.9096 - val_loss: 0.1858 - val_sparse_categorical_accuracy: 0.9053
# Epoch 77/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.2159 - sparse_categorical_accuracy: 0.9196 - val_loss: 0.2111 - val_sparse_categorical_accuracy: 0.8523
# Epoch 78/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1789 - sparse_categorical_accuracy: 0.8912 - val_loss: 0.1604 - val_sparse_categorical_accuracy: 0.9053
# Epoch 79/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.2118 - sparse_categorical_accuracy: 0.8511 - val_loss: 0.1726 - val_sparse_categorical_accuracy: 1.0000
# Epoch 80/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.1756 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.1819 - val_sparse_categorical_accuracy: 0.8523
# Epoch 81/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1835 - sparse_categorical_accuracy: 0.8989 - val_loss: 0.1878 - val_sparse_categorical_accuracy: 0.8523
# Epoch 82/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1793 - sparse_categorical_accuracy: 0.8721 - val_loss: 0.1519 - val_sparse_categorical_accuracy: 0.9053
# Epoch 83/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.1738 - sparse_categorical_accuracy: 0.8849 - val_loss: 0.1566 - val_sparse_categorical_accuracy: 1.0000
# Epoch 84/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1732 - sparse_categorical_accuracy: 0.9143 - val_loss: 0.1773 - val_sparse_categorical_accuracy: 0.8523
# Epoch 85/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1698 - sparse_categorical_accuracy: 0.9159 - val_loss: 0.1746 - val_sparse_categorical_accuracy: 0.8523
# Epoch 86/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1455 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.1591 - val_sparse_categorical_accuracy: 0.8523
# Epoch 87/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1695 - sparse_categorical_accuracy: 0.8901 - val_loss: 0.1487 - val_sparse_categorical_accuracy: 0.9053
# Epoch 88/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1834 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.1504 - val_sparse_categorical_accuracy: 0.9053
# Epoch 89/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1662 - sparse_categorical_accuracy: 0.9143 - val_loss: 0.1453 - val_sparse_categorical_accuracy: 0.9053
# Epoch 90/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.1841 - sparse_categorical_accuracy: 0.8574 - val_loss: 0.1496 - val_sparse_categorical_accuracy: 1.0000
# Epoch 91/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1575 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.2088 - val_sparse_categorical_accuracy: 0.8523
# Epoch 92/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1715 - sparse_categorical_accuracy: 0.9036 - val_loss: 0.2129 - val_sparse_categorical_accuracy: 0.8523
# Epoch 93/100
# 17/17 [==============================] - 1s 35ms/step - loss: 0.2040 - sparse_categorical_accuracy: 0.8555 - val_loss: 0.2062 - val_sparse_categorical_accuracy: 0.8523
# Epoch 94/100
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1562 - sparse_categorical_accuracy: 0.9234 - val_loss: 0.1701 - val_sparse_categorical_accuracy: 0.8523
# Epoch 95/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1777 - sparse_categorical_accuracy: 0.8924 - val_loss: 0.1475 - val_sparse_categorical_accuracy: 1.0000
# Epoch 96/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1611 - sparse_categorical_accuracy: 0.9221 - val_loss: 0.1441 - val_sparse_categorical_accuracy: 0.9053
# Epoch 97/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1501 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.1440 - val_sparse_categorical_accuracy: 1.0000
# Epoch 98/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1763 - sparse_categorical_accuracy: 0.9237 - val_loss: 0.1465 - val_sparse_categorical_accuracy: 0.9053
# Epoch 99/100
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1870 - sparse_categorical_accuracy: 0.8608 - val_loss: 0.1686 - val_sparse_categorical_accuracy: 0.8523
# Epoch 100/100
# 17/17 [==============================] - 1s 33ms/step - loss: 0.1406 - sparse_categorical_accuracy: 0.9269 - val_loss: 0.1455 - val_sparse_categorical_accuracy: 1.0000

# %%
graficarMatrizConfusion(y_true = y_test, y_pred = np.argmax(model.predict(x_test),axis=1))

# %%
graficarMatrizConfusion(y_true = y_train, y_pred = np.argmax(model.predict(x_train),axis=1))
